# %% [markdown]
# # Listas

# %% [markdown]
# Vamos começar definindo uma string.

# %%
palavra = "Danilo Farias"

# %%
letras = list(palavra)

# %% [markdown]
# Observe que `palavra` é uma string, e por isso os métodos que podem ser aplicados a esta variável são os métodos associados a um objeto do tipo string, enquanto que `letras` é uma **lista**, com métodos associados a um objeto do tipo lista:

# %%
letras
# Out:
# ['D', 'a', 'n', 'i', 'l', 'o', ' ', 'F', 'a', 'r', 'i', 'a', 's']

# %%
type(letras)
# Out:
# list

# %%
dir(letras)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# Também podemos saber quantos itens tem uma lista:

# %%
len(letras)
# Out:
# 13

# %% [markdown]
# O acesso a cada elemento de uma lista é feito da mesma maneira como acessamos os caracteres de uma string (lembrando que o índice do primeiro elemento de uma lista, no Python, é 0)

# %%
letras[0]
# Out:
# 'D'

# %% [markdown]
# Também podemos acessar o último elemento de uma lista usando um índice especial:

# %%
letras[-1]
# Out:
# 's'

# %% [markdown]
# Na verdade, índices negativos funcionam exatamente como esperaríamos:

# %%
letras[-3]
# Out:
# 'i'

# %% [markdown]
# ---
#
# Alguns métodos especiais que são bastante interessantes:

# %% [markdown]
# O método `append` acrescenta ao final da lista algum item:

# %%
frase = "O dia está lindo"

# %%
pedacos = frase.split()

# %%
pedacos
# Out:
# ['O', 'dia', 'está', 'lindo']

# %%
pedacos.append("!")

# %%
pedacos
# Out:
# ['O', 'dia', 'está', 'lindo', '!', '!', '!']

# %% [markdown]
# O método `insert` acrescenta um item à lista, na posição indicada:

# %%
pedacos.insert(3,"mais")

# %%
pedacos
# Out:
# ['O', 'dia', 'está', 'mais', 'lindo', '!', '!', '!']

# %% [markdown]
# Em Python, o **operador** `del` pode ser usado para excluir um item de uma lista, dado seu índice:

# %%
del pedacos[3]

# %%
pedacos
# Out:
# ['O', 'dia', 'está', 'lindo', '!', '!', '!']

# %% [markdown]
# No entanto, é mais usual excluirmos um item da lista usando o método `pop` (que exclui um item selecionado pelo seu índice, assim como o operador `del`) ou o método `remove` (que remove um item da lista selecionado pelo seu *valor*):

# %%
pedacos.remove("está")

# %%
pedacos
# Out:
# ['O', 'dia', 'lindo']

# %% [markdown]
# O método `pop` é interessante pois retorna, ao final de sua execução, o valor do item que foi removido:

# %%
pedacos.pop(3)
# Out:
# '!'

# %% [markdown]
# (o valor retornado aparece como saída da célula anterior.)

# %% [markdown]
# Podemos também descobrir o índice de um item da lista, dado seu valor:

# %%
pedacos.index("dia")
# Out:
# 1

# %% [markdown]
# Para descobrirmos se determinado valor está em uma lista, usamos a seguinte sintaxe:

# %%
"!" in pedacos
# Out:
# False

# %% [markdown]
# Veja que o método `pop` modificou a variável pedaços!

# %% [markdown]
# Observe que na lista `pedacos`, cada entrada também pode ser vista como uma lista!

# %%
pedacos[1]
# Out:
# 'dia'

# %% [markdown]
# Nesse caso, temos uma lista de listas, e assim podemos acessar cada um dos itens dessas sublistas:

# %%
pedacos[1][0]
# Out:
# 'd'

# %% [markdown]
# Tome um tempo para entender a sintaxe acima...

# %% [markdown]
# ## Slicing
#
# We can select pieces of a list (or string) easily using the concept of *slicing*.

# %% [markdown]
# Observe que, com um parâmetro a mais, podemos selecionar os elementos da lista de 2 em 2:

# %%
numeros = [1,3,6,9,12,15,18,21]

# %%
numeros[0]
# Out:
# 1

# %%
numeros[-1]
# Out:
# 21

# %% [markdown]
# Para selecionarmos itens com índices 3 até 5, usamos

# %%
numeros[3:6]
# Out:
# [9, 12, 15]

# %% [markdown]
# Eu sei! Mas existe uma razão para que a saída desse comando não inclua o item com índice 6: quanto dizemos `lista[início:fim]`, o resultado é uma lista com `fim-início` elementos.

# %% [markdown]
# Observe que, com um parâmetro a mais, podemos selecionar os elementos da lista de 2 em 2:

# %%
numeros[0:11:3]
# Out:
# [1, 9, 18]

# %% [markdown]
# Podemos gerar uma nova lista contendo pedaços da lista original:

# %%
numeros = [numeros[4:6],numeros[3:8]]
print(numeros)
# Out:
# [[12, 15], [9, 12, 15, 18, 21]]

# %% [markdown]
# Infelizmente, o resultado acima é uma lista de listas: cada elemento da lista é, por sua vez, uma outra lista:

# %%
numeros[0]
# Out:
# [12, 15]

# %% [markdown]
# Assim, para acessarmos um elemento individual da lista numeros, precisamos utilizar um índice para a lista externa, e outro índice para a lista interna:

# %%
numeros[0][1]
# Out:
# 15

# %% [markdown]
# Para transformarmos aquela lista de listas em uma lista simples, podemos usar o comando abaixo (admito que é um pouco mágico, mas funciona! ;))

# %%
lista = [item for sublist in numeros for item in sublist]
lista
# Out:
# [12, 15, 9, 12, 15, 18, 21]

# %% [markdown]
# Para entender o exemplo acima, dê uma olhada no Notebook Extra - List Comprehensions.
